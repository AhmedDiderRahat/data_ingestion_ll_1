# %% [markdown]
# ### Read text files

# %%
import bz2
import logging
import re
import pandas as pd
from datetime import datetime
from pprint import pprint

# %%
def parse_line(line):
    match = re.search(
        r'of (\d+).*started at ([^ ]+).*paid \$(\d+\.\d)',
        line)
    if not match:
        return None
    
    return {
        'count': int(match.group(1)),
        'start': (pd.to_datetime(match.group(2))).to_pydatetime(),
        'amount': float(match.group(3))
    }

# %%
def iter_rides(file_name):
    with bz2.open(file_name, 'rt') as fp:
        for lnum, line in enumerate(fp, 1):
            record = parse_line(line)  # line
            yield record

# %%
if __name__ == '__main__':
    for n, ride in enumerate(iter_rides('taxi.log.bz2')):
        pprint(ride)
# Out:
# {'amount': 20.5,
#  'count': 1,
#  'start': datetime.datetime(2018, 10, 31, 7, 10, 55)}
# {'amount': 13.8,
#  'count': 5,
#  'start': datetime.datetime(2018, 10, 31, 16, 38, 25)}
# {'amount': 11.3,
#  'count': 1,
#  'start': datetime.datetime(2018, 10, 31, 20, 23, 41)}
# {'amount': 5.8,
#  'count': 1,
#  'start': datetime.datetime(2018, 10, 31, 22, 44, 24)}
# {'amount': 13.5,
#  'count': 1,
#  'start': datetime.datetime(2018, 10, 31, 23, 22, 18)}
# {'amount': 24.3,
#  'count': 1,
#  'start': datetime.datetime(2018, 10, 31, 23, 27, 39)}
# {'amount': 11.6,
#  'count': 1,
#  'start': datetime.datetime(2018, 10, 31, 23, 40, 55)}
# {'amount': 11.3,
#  'count': 1,
#  'start': datetime.datetime(2018, 10, 31, 23, 45, 53)}
# {'amount': 6.8,
#  'count': 1,
#  'start': datetime.datetime(2018, 10, 31, 23, 46, 42)}
# {'amount': 17.8,
#  'count': 1,
#  'start': datetime.datetime(2018, 10, 31, 23, 47, 30)}
# {'amount': 18.8,
#  'count': 1,
#  'start': datetime.datetime(2018, 10, 31, 23, 47, 46)}
# {'amount': 8.8,
#  'count': 2,
#  'start': datetime.datetime(2018, 10, 31, 23, 52, 54)}
# {'amount': 5.3,
#  'count': 1,
#  'start': datetime.datetime(2018, 10, 31, 23, 56, 25)}
# {'amount': 20.1,
#  'count': 1,
#  'start': datetime.datetime(2018, 10, 31, 23, 56, 33)}
# {'amount': 12.3,
#  'count': 1,
#  'start': datetime.datetime(2018, 10, 31, 23, 56, 49)}
# {'amount': 18.9,
#  'count': 1,
#  'start': datetime.datetime(2018, 10, 31, 23, 57, 10)}
# {'amount': 8.3,
#  'count': 1,
#  'start': datetime.datetime(2018, 10, 31, 23, 57, 42)}
# {'amount': 42.3,
#  'count': 6,
#  'start': datetime.datetime(2018, 10, 31, 23, 58, 26)}
# {'amount': 10.1,
#  'count': 1,
#  'start': datetime.datetime(2018, 10, 31, 23, 58, 56)}
# {'amount': 8.3,
#  'count': 2,
#  'start': datetime.datetime(2018, 10, 31, 23, 59, 13)}
# {'amount': 16.3,
#  'count': 2,
#  'start': datetime.datetime(2018, 10, 31, 23, 59, 18)}
# {'amount': 25.3,
#  'count': 5,
#  'start': datetime.datetime(2018, 10, 31, 23, 59, 47)}
# {'amount': 10.7, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 0)}
# {'amount': 18.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 0)}
# {'amount': 10.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 0, 5)}
# {'amount': 12.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 0, 6)}
# {'amount': 12.2, 'count': 6, 'start': datetime.datetime(2018, 11, 1, 0, 0, 12)}
# {'amount': 31.5, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 0, 13)}
# {'amount': 19.3, 'count': 5, 'start': datetime.datetime(2018, 11, 1, 0, 0, 24)}
# {'amount': 63.9, 'count': 2, 'start': datetime.datetime(2018, 11, 1, 0, 0, 26)}
# {'amount': 7.5, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 0, 29)}
# {'amount': 45.9, 'count': 2, 'start': datetime.datetime(2018, 11, 1, 0, 0, 29)}
# {'amount': 14.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 0, 30)}
# {'amount': 15.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 0, 32)}
# {'amount': 21.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 0, 34)}
# {'amount': 6.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 0, 35)}
# {'amount': 31.5, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 0, 37)}
# {'amount': 11.7, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 0, 38)}
# {'amount': 8.8, 'count': 5, 'start': datetime.datetime(2018, 11, 1, 0, 0, 58)}
# {'amount': 10.1, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 1)}
# {'amount': 14.0, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 1, 2)}
# {'amount': 10.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 1, 5)}
# {'amount': 19.8, 'count': 3, 'start': datetime.datetime(2018, 11, 1, 0, 1, 5)}
# {'amount': 19.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 1, 12)}
# {'amount': 9.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 1, 28)}
# {'amount': 13.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 1, 32)}
# {'amount': 6.3, 'count': 4, 'start': datetime.datetime(2018, 11, 1, 0, 1, 33)}
# {'amount': 14.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 1, 36)}
# {'amount': 5.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 1, 37)}
# {'amount': 6.8, 'count': 2, 'start': datetime.datetime(2018, 11, 1, 0, 1, 41)}
# {'amount': 13.3, 'count': 2, 'start': datetime.datetime(2018, 11, 1, 0, 1, 54)}
# {'amount': 4.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 1, 56)}
# {'amount': 11.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 1, 57)}
# {'amount': 9.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 1, 57)}
# {'amount': 6.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 2, 2)}
# {'amount': 16.6, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 2, 4)}
# {'amount': 23.1, 'count': 2, 'start': datetime.datetime(2018, 11, 1, 0, 2, 6)}
# {'amount': 19.5, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 2, 7)}
# {'amount': 14.3, 'count': 2, 'start': datetime.datetime(2018, 11, 1, 0, 2, 11)}
# {'amount': 10.5, 'count': 3, 'start': datetime.datetime(2018, 11, 1, 0, 2, 14)}
# {'amount': 41.3, 'count': 3, 'start': datetime.datetime(2018, 11, 1, 0, 2, 14)}
# {'amount': 36.9, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 2, 16)}
# {'amount': 6.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 2, 17)}
# {'amount': 37.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 2, 18)}
# {'amount': 14.1, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 2, 21)}
# {'amount': 35.7, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 2, 22)}
# {'amount': 35.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 2, 24)}
# {'amount': 8.7, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 2, 24)}
# {'amount': 6.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 2, 27)}
# {'amount': 14.3, 'count': 3, 'start': datetime.datetime(2018, 11, 1, 0, 2, 30)}
# {'amount': 23.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 2, 31)}
# {'amount': 11.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 2, 32)}
# {'amount': 12.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 2, 39)}
# {'amount': 6.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 2, 45)}
# {'amount': 10.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 2, 46)}
# {'amount': 9.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 2, 49)}
# {'amount': 6.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 2, 51)}
# {'amount': 21.9, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 2, 57)}
# {'amount': 18.3, 'count': 3, 'start': datetime.datetime(2018, 11, 1, 0, 2, 58)}
# {'amount': 5.8, 'count': 3, 'start': datetime.datetime(2018, 11, 1, 0, 2, 59)}
# {'amount': 5.7, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 3, 3)}
# {'amount': 6.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 3, 6)}
# {'amount': 34.3, 'count': 2, 'start': datetime.datetime(2018, 11, 1, 0, 3, 12)}
# {'amount': 10.3, 'count': 2, 'start': datetime.datetime(2018, 11, 1, 0, 3, 22)}
# {'amount': 12.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 3, 22)}
# {'amount': 8.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 3, 24)}
# {'amount': 9.9, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 3, 28)}
# {'amount': 8.1, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 3, 28)}
# {'amount': 47.3, 'count': 2, 'start': datetime.datetime(2018, 11, 1, 0, 3, 29)}
# {'amount': 11.1, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 3, 32)}
# {'amount': 12.0, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 3, 37)}
# {'amount': 14.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 3, 45)}
# {'amount': 7.3, 'count': 2, 'start': datetime.datetime(2018, 11, 1, 0, 3, 46)}
# {'amount': 11.7, 'count': 2, 'start': datetime.datetime(2018, 11, 1, 0, 3, 50)}
# {'amount': 27.9, 'count': 2, 'start': datetime.datetime(2018, 11, 1, 0, 3, 51)}
# {'amount': 23.7, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 3, 57)}
# {'amount': 11.0, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 3, 57)}
# {'amount': 19.8, 'count': 2, 'start': datetime.datetime(2018, 11, 1, 0, 3, 59)}
# {'amount': 30.8, 'count': 6, 'start': datetime.datetime(2018, 11, 1, 0, 4, 16)}
# {'amount': 12.2, 'count': 5, 'start': datetime.datetime(2018, 11, 1, 0, 4, 19)}
# {'amount': 40.6, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 4, 20)}
# {'amount': 26.1, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 4, 20)}
# {'amount': 9.9, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 4, 23)}
# {'amount': 7.3, 'count': 2, 'start': datetime.datetime(2018, 11, 1, 0, 4, 24)}
# {'amount': 7.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 4, 27)}
# {'amount': 32.8, 'count': 5, 'start': datetime.datetime(2018, 11, 1, 0, 4, 30)}
# {'amount': 12.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 4, 30)}
# {'amount': 32.7, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 4, 38)}
# {'amount': 26.7, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 4, 41)}
# {'amount': 11.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 4, 41)}
# {'amount': 19.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 4, 42)}
# {'amount': 36.9, 'count': 2, 'start': datetime.datetime(2018, 11, 1, 0, 4, 50)}
# {'amount': 16.8, 'count': 2, 'start': datetime.datetime(2018, 11, 1, 0, 4, 51)}
# {'amount': 7.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 4, 52)}
# {'amount': 12.2, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 4, 53)}
# {'amount': 23.1, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 4, 53)}
# {'amount': 18.3, 'count': 3, 'start': datetime.datetime(2018, 11, 1, 0, 4, 57)}
# {'amount': 5.7, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 5, 1)}
# {'amount': 43.5, 'count': 4, 'start': datetime.datetime(2018, 11, 1, 0, 5, 1)}
# {'amount': 7.3, 'count': 3, 'start': datetime.datetime(2018, 11, 1, 0, 5, 8)}
# {'amount': 7.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 5, 11)}
# {'amount': 14.0, 'count': 3, 'start': datetime.datetime(2018, 11, 1, 0, 5, 15)}
# {'amount': 17.1, 'count': 3, 'start': datetime.datetime(2018, 11, 1, 0, 5, 16)}
# {'amount': 18.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 5, 17)}
# {'amount': 19.5, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 5, 18)}
# {'amount': 25.5, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 5, 19)}
# {'amount': 14.7, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 5, 24)}
# {'amount': 10.5, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 5, 25)}
# {'amount': 9.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 5, 28)}
# {'amount': 49.2, 'count': 2, 'start': datetime.datetime(2018, 11, 1, 0, 5, 32)}
# {'amount': 10.3, 'count': 3, 'start': datetime.datetime(2018, 11, 1, 0, 5, 40)}
# {'amount': 9.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 5, 43)}
# {'amount': 17.1, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 5, 49)}
# {'amount': 17.1, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 5, 50)}
# {'amount': 13.5, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 5, 57)}
# {'amount': 11.7, 'count': 2, 'start': datetime.datetime(2018, 11, 1, 0, 6, 1)}
# {'amount': 6.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 6, 2)}
# {'amount': 14.3, 'count': 0, 'start': datetime.datetime(2018, 11, 1, 0, 6, 6)}
# {'amount': 36.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 6, 8)}
# {'amount': 7.3, 'count': 0, 'start': datetime.datetime(2018, 11, 1, 0, 6, 8)}
# {'amount': 20.7, 'count': 4, 'start': datetime.datetime(2018, 11, 1, 0, 6, 11)}
# {'amount': 29.1, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 6, 15)}
# {'amount': 31.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 6, 29)}
# {'amount': 7.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 6, 36)}
# {'amount': 11.8, 'count': 5, 'start': datetime.datetime(2018, 11, 1, 0, 6, 47)}
# {'amount': 8.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 6, 53)}
# {'amount': 21.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 6, 55)}
# {'amount': 14.8, 'count': 6, 'start': datetime.datetime(2018, 11, 1, 0, 6, 57)}
# {'amount': 20.3, 'count': 2, 'start': datetime.datetime(2018, 11, 1, 0, 7)}
# {'amount': 52.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 7, 7)}
# {'amount': 23.5, 'count': 5, 'start': datetime.datetime(2018, 11, 1, 0, 7, 11)}
# {'amount': 21.3, 'count': 2, 'start': datetime.datetime(2018, 11, 1, 0, 7, 16)}
# {'amount': 16.3, 'count': 2, 'start': datetime.datetime(2018, 11, 1, 0, 7, 16)}
# {'amount': 3.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 7, 17)}
# {'amount': 17.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 7, 18)}
# {'amount': 8.3, 'count': 6, 'start': datetime.datetime(2018, 11, 1, 0, 7, 18)}
# {'amount': 9.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 7, 23)}
# {'amount': 17.1, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 7, 24)}
# {'amount': 14.7, 'count': 2, 'start': datetime.datetime(2018, 11, 1, 0, 7, 29)}
# {'amount': 34.3, 'count': 3, 'start': datetime.datetime(2018, 11, 1, 0, 7, 40)}
# {'amount': 20.7, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 7, 46)}
# {'amount': 11.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 7, 46)}
# {'amount': 10.8, 'count': 2, 'start': datetime.datetime(2018, 11, 1, 0, 7, 47)}
# {'amount': 8.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 7, 48)}
# {'amount': 6.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 7, 51)}
# {'amount': 14.1, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 7, 51)}
# {'amount': 63.9, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 7, 55)}
# {'amount': 9.9, 'count': 2, 'start': datetime.datetime(2018, 11, 1, 0, 7, 59)}
# {'amount': 14.1, 'count': 6, 'start': datetime.datetime(2018, 11, 1, 0, 8, 7)}
# {'amount': 6.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 8, 14)}
# {'amount': 13.8, 'count': 4, 'start': datetime.datetime(2018, 11, 1, 0, 8, 14)}
# {'amount': 12.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 8, 16)}
# {'amount': 15.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 8, 16)}
# {'amount': 18.7, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 8, 19)}
# {'amount': 15.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 8, 21)}
# {'amount': 12.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 8, 26)}
# {'amount': 6.0, 'count': 6, 'start': datetime.datetime(2018, 11, 1, 0, 8, 26)}
# {'amount': 17.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 8, 32)}
# {'amount': 11.7, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 8, 34)}
# {'amount': 6.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 8, 36)}
# {'amount': 21.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 8, 37)}
# {'amount': 11.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 8, 40)}
# {'amount': 11.7, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 8, 46)}
# {'amount': 8.1, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 8, 47)}
# {'amount': 6.8, 'count': 2, 'start': datetime.datetime(2018, 11, 1, 0, 8, 53)}
# {'amount': 12.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 8, 59)}
# {'amount': 15.3, 'count': 6, 'start': datetime.datetime(2018, 11, 1, 0, 8, 59)}
# {'amount': 11.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 9, 1)}
# {'amount': 15.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 9, 19)}
# {'amount': 5.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 9, 23)}
# {'amount': 14.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 9, 26)}
# {'amount': 32.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 9, 27)}
# {'amount': 17.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 9, 33)}
# {'amount': 13.5, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 9, 36)}
# {'amount': 7.5, 'count': 2, 'start': datetime.datetime(2018, 11, 1, 0, 9, 38)}
# {'amount': 11.4, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 9, 42)}
# {'amount': 8.7, 'count': 3, 'start': datetime.datetime(2018, 11, 1, 0, 9, 44)}
# {'amount': 8.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 9, 46)}
# {'amount': 6.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 9, 51)}
# {'amount': 12.8, 'count': 2, 'start': datetime.datetime(2018, 11, 1, 0, 9, 51)}
# {'amount': 40.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 9, 53)}
# {'amount': 23.1, 'count': 6, 'start': datetime.datetime(2018, 11, 1, 0, 9, 58)}
# {'amount': 7.2, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 9, 59)}
# {'amount': 6.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 9, 59)}
# {'amount': 8.7, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 10, 4)}
# {'amount': 12.3, 'count': 2, 'start': datetime.datetime(2018, 11, 1, 0, 10, 12)}
# {'amount': 18.9, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 10, 16)}
# {'amount': 17.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 10, 17)}
# {'amount': 5.7, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 10, 21)}
# {'amount': 4.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 10, 21)}
# {'amount': 19.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 10, 24)}
# {'amount': 12.0, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 10, 30)}
# {'amount': 26.7, 'count': 6, 'start': datetime.datetime(2018, 11, 1, 0, 10, 34)}
# {'amount': 14.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 10, 34)}
# {'amount': 11.3, 'count': 3, 'start': datetime.datetime(2018, 11, 1, 0, 10, 35)}
# {'amount': 11.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 10, 41)}
# {'amount': 23.1, 'count': 2, 'start': datetime.datetime(2018, 11, 1, 0, 10, 41)}
# {'amount': 9.3, 'count': 2, 'start': datetime.datetime(2018, 11, 1, 0, 10, 41)}
# {'amount': 18.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 10, 41)}
# {'amount': 12.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 10, 42)}
# {'amount': 9.9, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 10, 43)}
# {'amount': 9.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 10, 51)}
# {'amount': 20.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 10, 52)}
# {'amount': 10.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 10, 53)}
# {'amount': 5.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 10, 54)}
# {'amount': 12.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 10, 54)}
# {'amount': 13.5, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 10, 55)}
# {'amount': 6.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 11)}
# {'amount': 6.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 11, 1)}
# {'amount': 9.3, 'count': 2, 'start': datetime.datetime(2018, 11, 1, 0, 11, 1)}
# {'amount': 7.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 11, 3)}
# {'amount': 17.1, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 11, 6)}
# {'amount': 12.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 11, 7)}
# {'amount': 9.9, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 11, 12)}
# {'amount': 16.3, 'count': 2, 'start': datetime.datetime(2018, 11, 1, 0, 11, 13)}
# {'amount': 9.7, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 11, 21)}
# {'amount': 8.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 11, 26)}
# {'amount': 9.9, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 11, 28)}
# {'amount': 19.5, 'count': 2, 'start': datetime.datetime(2018, 11, 1, 0, 11, 30)}
# {'amount': 24.9, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 11, 36)}
# {'amount': 13.8, 'count': 4, 'start': datetime.datetime(2018, 11, 1, 0, 11, 38)}
# {'amount': 6.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 11, 39)}
# {'amount': 10.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 11, 40)}
# {'amount': 38.7, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 11, 40)}
# {'amount': 14.0, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 11, 42)}
# {'amount': 8.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 11, 43)}
# {'amount': 14.8, 'count': 2, 'start': datetime.datetime(2018, 11, 1, 0, 11, 52)}
# {'amount': 8.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 11, 56)}
# {'amount': 12.9, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 11, 59)}
# {'amount': 8.3, 'count': 3, 'start': datetime.datetime(2018, 11, 1, 0, 12, 2)}
# {'amount': 15.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 12, 6)}
# {'amount': 15.9, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 12, 20)}
# {'amount': 30.3, 'count': 2, 'start': datetime.datetime(2018, 11, 1, 0, 12, 21)}
# {'amount': 6.8, 'count': 5, 'start': datetime.datetime(2018, 11, 1, 0, 12, 22)}
# {'amount': 19.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 12, 24)}
# {'amount': 19.8, 'count': 2, 'start': datetime.datetime(2018, 11, 1, 0, 12, 25)}
# {'amount': 6.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 12, 26)}
# {'amount': 20.1, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 12, 30)}
# {'amount': 11.1, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 12, 30)}
# {'amount': 8.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 12, 31)}
# {'amount': 13.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 12, 31)}
# {'amount': 8.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 12, 38)}
# {'amount': 18.9, 'count': 2, 'start': datetime.datetime(2018, 11, 1, 0, 12, 39)}
# {'amount': 14.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 12, 39)}
# {'amount': 6.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 12, 56)}
# {'amount': 20.1, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 12, 58)}
# {'amount': 7.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 12, 59)}
# {'amount': 9.7, 'count': 2, 'start': datetime.datetime(2018, 11, 1, 0, 13, 4)}
# {'amount': 19.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 13, 5)}
# {'amount': 10.5, 'count': 4, 'start': datetime.datetime(2018, 11, 1, 0, 13, 7)}
# {'amount': 12.9, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 13, 13)}
# {'amount': 35.3, 'count': 6, 'start': datetime.datetime(2018, 11, 1, 0, 13, 14)}
# {'amount': 12.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 13, 15)}
# {'amount': 18.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 13, 16)}
# {'amount': 41.1, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 13, 24)}
# {'amount': 14.0, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 13, 27)}
# {'amount': 9.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 13, 27)}
# {'amount': 22.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 13, 28)}
# {'amount': 4.3, 'count': 6, 'start': datetime.datetime(2018, 11, 1, 0, 13, 29)}
# {'amount': 8.7, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 13, 41)}
# {'amount': 24.3, 'count': 3, 'start': datetime.datetime(2018, 11, 1, 0, 13, 43)}
# {'amount': 9.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 13, 46)}
# {'amount': 5.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 13, 52)}
# {'amount': 17.1, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 13, 54)}
# {'amount': 4.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 13, 58)}
# {'amount': 17.0, 'count': 3, 'start': datetime.datetime(2018, 11, 1, 0, 14)}
# {'amount': 12.2, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 14, 2)}
# {'amount': 12.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 14, 8)}
# {'amount': 8.5, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 14, 11)}
# {'amount': 20.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 14, 18)}
# {'amount': 8.7, 'count': 3, 'start': datetime.datetime(2018, 11, 1, 0, 14, 21)}
# {'amount': 15.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 14, 23)}
# {'amount': 10.8, 'count': 5, 'start': datetime.datetime(2018, 11, 1, 0, 14, 25)}
# {'amount': 14.1, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 14, 26)}
# {'amount': 10.5, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 14, 29)}
# {'amount': 11.6, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 14, 30)}
# {'amount': 13.8, 'count': 2, 'start': datetime.datetime(2018, 11, 1, 0, 14, 31)}
# {'amount': 13.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 14, 32)}
# {'amount': 10.0, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 14, 35)}
# {'amount': 23.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 14, 38)}
# {'amount': 8.1, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 14, 44)}
# {'amount': 9.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 14, 44)}
# {'amount': 8.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 14, 46)}
# {'amount': 28.9, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 14, 53)}
# {'amount': 8.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 14, 55)}
# {'amount': 7.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 15, 4)}
# {'amount': 10.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 15, 6)}
# {'amount': 7.5, 'count': 5, 'start': datetime.datetime(2018, 11, 1, 0, 15, 7)}
# {'amount': 8.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 15, 11)}
# {'amount': 35.3, 'count': 5, 'start': datetime.datetime(2018, 11, 1, 0, 15, 12)}
# {'amount': 10.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 15, 17)}
# {'amount': 39.3, 'count': 2, 'start': datetime.datetime(2018, 11, 1, 0, 15, 18)}
# {'amount': 28.5, 'count': 2, 'start': datetime.datetime(2018, 11, 1, 0, 15, 19)}
# {'amount': 10.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 15, 20)}
# {'amount': 4.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 15, 27)}
# {'amount': 17.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 15, 30)}
# {'amount': 18.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 15, 31)}
# {'amount': 9.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 15, 31)}
# {'amount': 34.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 15, 41)}
# {'amount': 10.5, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 15, 45)}
# {'amount': 22.2, 'count': 2, 'start': datetime.datetime(2018, 11, 1, 0, 15, 50)}
# {'amount': 13.5, 'count': 5, 'start': datetime.datetime(2018, 11, 1, 0, 15, 50)}
# {'amount': 11.1, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 15, 51)}
# {'amount': 41.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 15, 55)}
# {'amount': 11.8, 'count': 2, 'start': datetime.datetime(2018, 11, 1, 0, 16, 6)}
# {'amount': 18.3, 'count': 5, 'start': datetime.datetime(2018, 11, 1, 0, 16, 10)}
# {'amount': 9.9, 'count': 2, 'start': datetime.datetime(2018, 11, 1, 0, 16, 24)}
# {'amount': 12.9, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 16, 26)}
# {'amount': 15.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 16, 27)}
# {'amount': 11.1, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 16, 30)}
# {'amount': 11.0, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 16, 31)}
# {'amount': 17.7, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 16, 38)}
# {'amount': 8.8, 'count': 6, 'start': datetime.datetime(2018, 11, 1, 0, 16, 39)}
# {'amount': 8.8, 'count': 3, 'start': datetime.datetime(2018, 11, 1, 0, 16, 47)}
# {'amount': 27.9, 'count': 5, 'start': datetime.datetime(2018, 11, 1, 0, 16, 49)}
# {'amount': 10.5, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 16, 53)}
# {'amount': 12.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 16, 56)}
# {'amount': 5.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 17)}
# {'amount': 14.7, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 17, 4)}
# {'amount': 13.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 17, 5)}
# {'amount': 15.3, 'count': 5, 'start': datetime.datetime(2018, 11, 1, 0, 17, 5)}
# {'amount': 9.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 17, 15)}
# {'amount': 17.3, 'count': 3, 'start': datetime.datetime(2018, 11, 1, 0, 17, 35)}
# {'amount': 30.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 17, 39)}
# {'amount': 11.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 17, 42)}
# {'amount': 24.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 17, 48)}
# {'amount': 20.7, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 17, 49)}
# {'amount': 34.7, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 17, 50)}
# {'amount': 14.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 17, 53)}
# {'amount': 19.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 17, 56)}
# {'amount': 14.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 17, 57)}
# {'amount': 25.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 18)}
# {'amount': 22.9, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 18, 3)}
# {'amount': 5.3, 'count': 2, 'start': datetime.datetime(2018, 11, 1, 0, 18, 4)}
# {'amount': 5.7, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 18, 26)}
# {'amount': 23.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 18, 34)}
# {'amount': 25.3, 'count': 3, 'start': datetime.datetime(2018, 11, 1, 0, 18, 35)}
# {'amount': 9.5, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 18, 38)}
# {'amount': 17.3, 'count': 3, 'start': datetime.datetime(2018, 11, 1, 0, 18, 45)}
# {'amount': 5.3, 'count': 0, 'start': datetime.datetime(2018, 11, 1, 0, 18, 49)}
# {'amount': 11.3, 'count': 2, 'start': datetime.datetime(2018, 11, 1, 0, 18, 51)}
# {'amount': 6.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 18, 53)}
# {'amount': 20.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 19, 3)}
# {'amount': 9.3, 'count': 2, 'start': datetime.datetime(2018, 11, 1, 0, 19, 4)}
# {'amount': 33.9, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 19, 4)}
# {'amount': 15.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 19, 14)}
# {'amount': 5.9, 'count': 2, 'start': datetime.datetime(2018, 11, 1, 0, 19, 20)}
# {'amount': 12.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 19, 24)}
# {'amount': 15.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 19, 29)}
# {'amount': 15.8, 'count': 5, 'start': datetime.datetime(2018, 11, 1, 0, 19, 36)}
# {'amount': 25.8, 'count': 2, 'start': datetime.datetime(2018, 11, 1, 0, 19, 37)}
# {'amount': 17.7, 'count': 3, 'start': datetime.datetime(2018, 11, 1, 0, 19, 38)}
# {'amount': 31.5, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 19, 51)}
# {'amount': 8.5, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 19, 54)}
# {'amount': 9.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 19, 55)}
# {'amount': 100.3,
#  'count': 2,
#  'start': datetime.datetime(2018, 11, 1, 0, 19, 58)}
# {'amount': 8.8, 'count': 5, 'start': datetime.datetime(2018, 11, 1, 0, 19, 59)}
# {'amount': 7.5, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 19, 59)}
# {'amount': 20.7, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 20, 4)}
# {'amount': 12.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 20, 5)}
# {'amount': 13.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 20, 12)}
# {'amount': 20.7, 'count': 5, 'start': datetime.datetime(2018, 11, 1, 0, 20, 13)}
# {'amount': 7.0, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 20, 13)}
# {'amount': 33.9, 'count': 6, 'start': datetime.datetime(2018, 11, 1, 0, 20, 19)}
# {'amount': 24.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 20, 21)}
# {'amount': 11.2, 'count': 2, 'start': datetime.datetime(2018, 11, 1, 0, 20, 24)}
# {'amount': 23.1, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 20, 25)}
# {'amount': 5.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 20, 29)}
# {'amount': 12.3, 'count': 4, 'start': datetime.datetime(2018, 11, 1, 0, 20, 30)}
# {'amount': 8.5, 'count': 2, 'start': datetime.datetime(2018, 11, 1, 0, 20, 33)}
# {'amount': 6.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 20, 33)}
# {'amount': 10.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 20, 39)}
# {'amount': 11.7, 'count': 2, 'start': datetime.datetime(2018, 11, 1, 0, 20, 46)}
# {'amount': 12.9, 'count': 2, 'start': datetime.datetime(2018, 11, 1, 0, 20, 52)}
# {'amount': 12.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 20, 56)}
# {'amount': 8.7, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 20, 56)}
# {'amount': 14.1, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 20, 59)}
# {'amount': 9.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 21, 1)}
# {'amount': 25.0, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 21, 12)}
# {'amount': 7.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 21, 13)}
# {'amount': 8.5, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 21, 16)}
# {'amount': 15.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 21, 23)}
# {'amount': 4.8, 'count': 2, 'start': datetime.datetime(2018, 11, 1, 0, 21, 32)}
# {'amount': 18.5, 'count': 4, 'start': datetime.datetime(2018, 11, 1, 0, 21, 34)}
# {'amount': 24.3, 'count': 4, 'start': datetime.datetime(2018, 11, 1, 0, 21, 38)}
# {'amount': 9.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 21, 40)}
# {'amount': 19.5, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 21, 41)}
# {'amount': 12.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 21, 43)}
# {'amount': 11.1, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 21, 44)}
# {'amount': 15.3, 'count': 0, 'start': datetime.datetime(2018, 11, 1, 0, 21, 45)}
# {'amount': 6.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 21, 46)}
# {'amount': 14.8, 'count': 3, 'start': datetime.datetime(2018, 11, 1, 0, 21, 50)}
# {'amount': 10.5, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 21, 50)}
# {'amount': 22.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 21, 51)}
# {'amount': 11.4, 'count': 3, 'start': datetime.datetime(2018, 11, 1, 0, 21, 51)}
# {'amount': 11.8, 'count': 4, 'start': datetime.datetime(2018, 11, 1, 0, 22)}
# {'amount': 7.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 22, 3)}
# {'amount': 7.5, 'count': 3, 'start': datetime.datetime(2018, 11, 1, 0, 22, 5)}
# {'amount': 21.8, 'count': 3, 'start': datetime.datetime(2018, 11, 1, 0, 22, 9)}
# {'amount': 12.3, 'count': 4, 'start': datetime.datetime(2018, 11, 1, 0, 22, 10)}
# {'amount': 19.1, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 22, 13)}
# {'amount': 7.5, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 22, 21)}
# {'amount': 36.8, 'count': 4, 'start': datetime.datetime(2018, 11, 1, 0, 22, 25)}
# {'amount': 25.3, 'count': 2, 'start': datetime.datetime(2018, 11, 1, 0, 22, 38)}
# {'amount': 26.6, 'count': 2, 'start': datetime.datetime(2018, 11, 1, 0, 22, 49)}
# {'amount': 8.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 22, 50)}
# {'amount': 20.7, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 22, 53)}
# {'amount': 9.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 22, 55)}
# {'amount': 17.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 23, 3)}
# {'amount': 27.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 23, 7)}
# {'amount': 11.8, 'count': 6, 'start': datetime.datetime(2018, 11, 1, 0, 23, 9)}
# {'amount': 7.5, 'count': 2, 'start': datetime.datetime(2018, 11, 1, 0, 23, 12)}
# {'amount': 5.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 23, 13)}
# {'amount': 24.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 23, 14)}
# {'amount': 5.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 23, 16)}
# {'amount': 6.9, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 23, 20)}
# {'amount': 11.2, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 23, 21)}
# {'amount': 14.1, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 23, 40)}
# {'amount': 13.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 23, 50)}
# {'amount': 11.3, 'count': 2, 'start': datetime.datetime(2018, 11, 1, 0, 23, 51)}
# {'amount': 7.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 23, 52)}
# {'amount': 12.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 23, 57)}
# {'amount': 9.0, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 23, 58)}
# {'amount': 7.3, 'count': 2, 'start': datetime.datetime(2018, 11, 1, 0, 23, 58)}
# {'amount': 11.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 24, 4)}
# {'amount': 5.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 24, 10)}
# {'amount': 15.8, 'count': 2, 'start': datetime.datetime(2018, 11, 1, 0, 24, 13)}
# {'amount': 24.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 24, 13)}
# {'amount': 23.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 24, 21)}
# {'amount': 20.1, 'count': 2, 'start': datetime.datetime(2018, 11, 1, 0, 24, 34)}
# {'amount': 13.5, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 24, 34)}
# {'amount': 0.0, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 24, 43)}
# {'amount': 34.2, 'count': 2, 'start': datetime.datetime(2018, 11, 1, 0, 24, 43)}
# {'amount': 13.5, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 24, 47)}
# {'amount': 7.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 24, 50)}
# {'amount': 9.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 24, 52)}
# {'amount': 22.3, 'count': 2, 'start': datetime.datetime(2018, 11, 1, 0, 24, 54)}
# {'amount': 12.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 24, 56)}
# {'amount': 11.1, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 25, 2)}
# {'amount': 28.0, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 25, 15)}
# {'amount': 17.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 25, 25)}
# {'amount': 7.9, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 25, 26)}
# {'amount': 7.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 25, 40)}
# {'amount': 12.9, 'count': 2, 'start': datetime.datetime(2018, 11, 1, 0, 25, 41)}
# {'amount': 12.0, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 25, 45)}
# {'amount': 6.3, 'count': 6, 'start': datetime.datetime(2018, 11, 1, 0, 25, 47)}
# {'amount': 17.9, 'count': 5, 'start': datetime.datetime(2018, 11, 1, 0, 25, 54)}
# {'amount': 14.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 26)}
# {'amount': 11.1, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 26, 8)}
# {'amount': 33.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 26, 12)}
# {'amount': 6.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 26, 12)}
# {'amount': 9.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 26, 13)}
# {'amount': 40.2, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 26, 15)}
# {'amount': 12.9, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 26, 21)}
# {'amount': 37.3, 'count': 5, 'start': datetime.datetime(2018, 11, 1, 0, 26, 25)}
# {'amount': 12.9, 'count': 4, 'start': datetime.datetime(2018, 11, 1, 0, 26, 27)}
# {'amount': 8.7, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 26, 32)}
# {'amount': 10.5, 'count': 5, 'start': datetime.datetime(2018, 11, 1, 0, 26, 37)}
# {'amount': 7.5, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 26, 39)}
# {'amount': 26.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 26, 48)}
# {'amount': 18.9, 'count': 3, 'start': datetime.datetime(2018, 11, 1, 0, 26, 53)}
# {'amount': 14.7, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 26, 54)}
# {'amount': 11.1, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 26, 55)}
# {'amount': 23.7, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 26, 59)}
# {'amount': 23.7, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 27, 1)}
# {'amount': 8.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 27, 2)}
# {'amount': 14.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 27, 5)}
# {'amount': 13.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 27, 10)}
# {'amount': 7.5, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 27, 16)}
# {'amount': 11.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 27, 23)}
# {'amount': 8.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 27, 28)}
# {'amount': 10.5, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 27, 32)}
# {'amount': 9.9, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 27, 32)}
# {'amount': 33.9, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 27, 42)}
# {'amount': 24.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 27, 43)}
# {'amount': 15.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 27, 44)}
# {'amount': 7.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 27, 46)}
# {'amount': 24.9, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 27, 47)}
# {'amount': 33.5, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 27, 50)}
# {'amount': 23.1, 'count': 3, 'start': datetime.datetime(2018, 11, 1, 0, 27, 58)}
# {'amount': 12.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 28, 2)}
# {'amount': 12.3, 'count': 4, 'start': datetime.datetime(2018, 11, 1, 0, 28, 6)}
# {'amount': 12.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 28, 11)}
# {'amount': 9.9, 'count': 5, 'start': datetime.datetime(2018, 11, 1, 0, 28, 12)}
# {'amount': 6.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 28, 30)}
# {'amount': 22.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 28, 32)}
# {'amount': 26.0, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 28, 47)}
# {'amount': 10.8, 'count': 2, 'start': datetime.datetime(2018, 11, 1, 0, 28, 49)}
# {'amount': 9.8, 'count': 2, 'start': datetime.datetime(2018, 11, 1, 0, 28, 50)}
# {'amount': 28.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 28, 50)}
# {'amount': 12.9, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 29, 3)}
# {'amount': 18.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 29, 10)}
# {'amount': 8.8, 'count': 3, 'start': datetime.datetime(2018, 11, 1, 0, 29, 12)}
# {'amount': 9.9, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 29, 19)}
# {'amount': 10.7, 'count': 2, 'start': datetime.datetime(2018, 11, 1, 0, 29, 21)}
# {'amount': 10.5, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 29, 23)}
# {'amount': 9.8, 'count': 6, 'start': datetime.datetime(2018, 11, 1, 0, 29, 27)}
# {'amount': 12.9, 'count': 4, 'start': datetime.datetime(2018, 11, 1, 0, 29, 27)}
# {'amount': 14.7, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 29, 32)}
# {'amount': 8.1, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 29, 33)}
# {'amount': 33.5, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 29, 37)}
# {'amount': 11.1, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 29, 37)}
# {'amount': 19.5, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 29, 42)}
# {'amount': 11.1, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 29, 46)}
# {'amount': 28.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 29, 47)}
# {'amount': 6.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 29, 56)}
# {'amount': 8.3, 'count': 3, 'start': datetime.datetime(2018, 11, 1, 0, 29, 57)}
# {'amount': 20.1, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 29, 57)}
# {'amount': 13.5, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 29, 58)}
# {'amount': 18.9, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 30)}
# {'amount': 33.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 30, 10)}
# {'amount': 26.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 30, 10)}
# {'amount': 6.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 30, 13)}
# {'amount': 25.7, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 30, 13)}
# {'amount': 48.8, 'count': 3, 'start': datetime.datetime(2018, 11, 1, 0, 30, 19)}
# {'amount': 25.5, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 30, 19)}
# {'amount': 35.1, 'count': 4, 'start': datetime.datetime(2018, 11, 1, 0, 30, 19)}
# {'amount': 23.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 30, 21)}
# {'amount': 6.9, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 30, 30)}
# {'amount': 7.5, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 30, 34)}
# {'amount': 24.3, 'count': 2, 'start': datetime.datetime(2018, 11, 1, 0, 30, 39)}
# {'amount': 26.1, 'count': 2, 'start': datetime.datetime(2018, 11, 1, 0, 30, 41)}
# {'amount': 7.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 30, 44)}
# {'amount': 22.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 30, 45)}
# {'amount': 43.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 30, 50)}
# {'amount': 6.9, 'count': 2, 'start': datetime.datetime(2018, 11, 1, 0, 30, 53)}
# {'amount': 11.7, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 30, 54)}
# {'amount': 12.3, 'count': 5, 'start': datetime.datetime(2018, 11, 1, 0, 30, 55)}
# {'amount': 17.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 30, 58)}
# {'amount': 9.8, 'count': 3, 'start': datetime.datetime(2018, 11, 1, 0, 30, 58)}
# {'amount': 20.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 30, 59)}
# {'amount': 36.8, 'count': 4, 'start': datetime.datetime(2018, 11, 1, 0, 31, 15)}
# {'amount': 9.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 31, 20)}
# {'amount': 6.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 31, 20)}
# {'amount': 5.3, 'count': 2, 'start': datetime.datetime(2018, 11, 1, 0, 31, 32)}
# {'amount': 16.0, 'count': 3, 'start': datetime.datetime(2018, 11, 1, 0, 31, 35)}
# {'amount': 11.1, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 31, 37)}
# {'amount': 13.3, 'count': 3, 'start': datetime.datetime(2018, 11, 1, 0, 31, 38)}
# {'amount': 11.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 31, 40)}
# {'amount': 7.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 31, 42)}
# {'amount': 16.0, 'count': 2, 'start': datetime.datetime(2018, 11, 1, 0, 31, 52)}
# {'amount': 7.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 31, 53)}
# {'amount': 8.8, 'count': 5, 'start': datetime.datetime(2018, 11, 1, 0, 31, 53)}
# {'amount': 9.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 31, 57)}
# {'amount': 12.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 32)}
# {'amount': 12.9, 'count': 3, 'start': datetime.datetime(2018, 11, 1, 0, 32, 4)}
# {'amount': 27.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 32, 15)}
# {'amount': 16.8, 'count': 2, 'start': datetime.datetime(2018, 11, 1, 0, 32, 17)}
# {'amount': 7.5, 'count': 2, 'start': datetime.datetime(2018, 11, 1, 0, 32, 18)}
# {'amount': 8.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 32, 19)}
# {'amount': 31.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 32, 24)}
# {'amount': 8.1, 'count': 2, 'start': datetime.datetime(2018, 11, 1, 0, 32, 24)}
# {'amount': 22.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 32, 30)}
# {'amount': 20.7, 'count': 2, 'start': datetime.datetime(2018, 11, 1, 0, 32, 30)}
# {'amount': 8.8, 'count': 2, 'start': datetime.datetime(2018, 11, 1, 0, 32, 30)}
# {'amount': 15.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 32, 43)}
# {'amount': 6.8, 'count': 2, 'start': datetime.datetime(2018, 11, 1, 0, 32, 50)}
# {'amount': 13.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 33, 4)}
# {'amount': 19.1, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 33, 8)}
# {'amount': 11.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 33, 11)}
# {'amount': 12.8, 'count': 6, 'start': datetime.datetime(2018, 11, 1, 0, 33, 12)}
# {'amount': 6.9, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 33, 15)}
# {'amount': 16.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 33, 16)}
# {'amount': 6.8, 'count': 2, 'start': datetime.datetime(2018, 11, 1, 0, 33, 17)}
# {'amount': 7.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 33, 19)}
# {'amount': 13.5, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 33, 30)}
# {'amount': 10.5, 'count': 2, 'start': datetime.datetime(2018, 11, 1, 0, 33, 32)}
# {'amount': 6.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 33, 33)}
# {'amount': 27.9, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 33, 35)}
# {'amount': 9.7, 'count': 2, 'start': datetime.datetime(2018, 11, 1, 0, 33, 36)}
# {'amount': 11.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 33, 47)}
# {'amount': 10.5, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 33, 48)}
# {'amount': 4.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 33, 48)}
# {'amount': 9.8, 'count': 4, 'start': datetime.datetime(2018, 11, 1, 0, 33, 50)}
# {'amount': 8.1, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 33, 53)}
# {'amount': 6.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 34, 2)}
# {'amount': 7.5, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 0, 34, 9)}
# ...
# {'amount': 7.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 10, 54, 6)}
# {'amount': 23.7,
#  'count': 5,
#  'start': datetime.datetime(2018, 11, 1, 10, 54, 12)}
# {'amount': 16.5,
#  'count': 1,
#  'start': datetime.datetime(2018, 11, 1, 10, 54, 14)}
# {'amount': 13.5,
#  'count': 1,
#  'start': datetime.datetime(2018, 11, 1, 10, 54, 14)}
# {'amount': 8.7, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 10, 54, 20)}
# {'amount': 11.5,
#  'count': 1,
#  'start': datetime.datetime(2018, 11, 1, 10, 54, 30)}
# {'amount': 8.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 10, 54, 31)}
# {'amount': 11.3,
#  'count': 1,
#  'start': datetime.datetime(2018, 11, 1, 10, 54, 35)}
# {'amount': 8.0, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 10, 54, 41)}
# {'amount': 11.7,
#  'count': 1,
#  'start': datetime.datetime(2018, 11, 1, 10, 54, 44)}
# {'amount': 52.8,
#  'count': 1,
#  'start': datetime.datetime(2018, 11, 1, 10, 54, 47)}
# {'amount': 57.6,
#  'count': 1,
#  'start': datetime.datetime(2018, 11, 1, 10, 54, 50)}
# {'amount': 12.9,
#  'count': 1,
#  'start': datetime.datetime(2018, 11, 1, 10, 54, 50)}
# {'amount': 5.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 10, 54, 53)}
# {'amount': 49.2,
#  'count': 1,
#  'start': datetime.datetime(2018, 11, 1, 10, 54, 57)}
# {'amount': 13.8,
#  'count': 1,
#  'start': datetime.datetime(2018, 11, 1, 10, 54, 57)}
# {'amount': 6.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 10, 54, 58)}
# {'amount': 14.8,
#  'count': 1,
#  'start': datetime.datetime(2018, 11, 1, 10, 54, 59)}
# {'amount': 11.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 10, 55, 5)}
# {'amount': 38.8, 'count': 2, 'start': datetime.datetime(2018, 11, 1, 10, 55, 6)}
# {'amount': 21.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 10, 55, 9)}
# {'amount': 7.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 10, 55, 10)}
# {'amount': 11.2,
#  'count': 2,
#  'start': datetime.datetime(2018, 11, 1, 10, 55, 24)}
# {'amount': 18.3,
#  'count': 1,
#  'start': datetime.datetime(2018, 11, 1, 10, 55, 29)}
# {'amount': 44.3,
#  'count': 1,
#  'start': datetime.datetime(2018, 11, 1, 10, 55, 29)}
# {'amount': 10.8,
#  'count': 1,
#  'start': datetime.datetime(2018, 11, 1, 10, 55, 40)}
# {'amount': 11.7,
#  'count': 1,
#  'start': datetime.datetime(2018, 11, 1, 10, 55, 41)}
# {'amount': 7.4, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 10, 55, 47)}
# {'amount': 5.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 10, 55, 49)}
# {'amount': 11.1,
#  'count': 1,
#  'start': datetime.datetime(2018, 11, 1, 10, 55, 50)}
# {'amount': 11.4,
#  'count': 3,
#  'start': datetime.datetime(2018, 11, 1, 10, 55, 51)}
# {'amount': 15.3,
#  'count': 1,
#  'start': datetime.datetime(2018, 11, 1, 10, 55, 57)}
# {'amount': 12.8,
#  'count': 1,
#  'start': datetime.datetime(2018, 11, 1, 10, 55, 59)}
# {'amount': 5.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 10, 56, 3)}
# {'amount': 17.2, 'count': 2, 'start': datetime.datetime(2018, 11, 1, 10, 56, 5)}
# {'amount': 8.1, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 10, 56, 6)}
# {'amount': 11.7, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 10, 56, 9)}
# {'amount': 18.3,
#  'count': 2,
#  'start': datetime.datetime(2018, 11, 1, 10, 56, 12)}
# {'amount': 9.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 10, 56, 13)}
# {'amount': 7.2, 'count': 3, 'start': datetime.datetime(2018, 11, 1, 10, 56, 16)}
# {'amount': 23.7,
#  'count': 5,
#  'start': datetime.datetime(2018, 11, 1, 10, 56, 17)}
# {'amount': 5.1, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 10, 56, 18)}
# {'amount': 9.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 10, 56, 20)}
# {'amount': 13.3,
#  'count': 1,
#  'start': datetime.datetime(2018, 11, 1, 10, 56, 27)}
# {'amount': 10.5,
#  'count': 1,
#  'start': datetime.datetime(2018, 11, 1, 10, 56, 30)}
# {'amount': 7.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 10, 56, 30)}
# {'amount': 11.2,
#  'count': 1,
#  'start': datetime.datetime(2018, 11, 1, 10, 56, 31)}
# {'amount': 63.9,
#  'count': 1,
#  'start': datetime.datetime(2018, 11, 1, 10, 56, 32)}
# {'amount': 48.6,
#  'count': 2,
#  'start': datetime.datetime(2018, 11, 1, 10, 56, 32)}
# {'amount': 10.3,
#  'count': 1,
#  'start': datetime.datetime(2018, 11, 1, 10, 56, 34)}
# {'amount': 9.5, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 10, 56, 35)}
# {'amount': 14.3,
#  'count': 1,
#  'start': datetime.datetime(2018, 11, 1, 10, 56, 36)}
# {'amount': 10.3,
#  'count': 1,
#  'start': datetime.datetime(2018, 11, 1, 10, 56, 38)}
# {'amount': 11.3,
#  'count': 1,
#  'start': datetime.datetime(2018, 11, 1, 10, 56, 38)}
# {'amount': 11.1,
#  'count': 2,
#  'start': datetime.datetime(2018, 11, 1, 10, 56, 41)}
# {'amount': 6.8, 'count': 2, 'start': datetime.datetime(2018, 11, 1, 10, 56, 41)}
# {'amount': 26.0,
#  'count': 1,
#  'start': datetime.datetime(2018, 11, 1, 10, 56, 54)}
# {'amount': 9.9, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 10, 56, 58)}
# {'amount': 14.1, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 10, 57, 4)}
# {'amount': 16.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 10, 57, 6)}
# {'amount': 6.9, 'count': 5, 'start': datetime.datetime(2018, 11, 1, 10, 57, 7)}
# {'amount': 11.1,
#  'count': 1,
#  'start': datetime.datetime(2018, 11, 1, 10, 57, 14)}
# {'amount': 48.0,
#  'count': 1,
#  'start': datetime.datetime(2018, 11, 1, 10, 57, 15)}
# {'amount': 27.9,
#  'count': 2,
#  'start': datetime.datetime(2018, 11, 1, 10, 57, 16)}
# {'amount': 31.8,
#  'count': 1,
#  'start': datetime.datetime(2018, 11, 1, 10, 57, 16)}
# {'amount': 23.1,
#  'count': 2,
#  'start': datetime.datetime(2018, 11, 1, 10, 57, 17)}
# {'amount': 9.8, 'count': 0, 'start': datetime.datetime(2018, 11, 1, 10, 57, 17)}
# {'amount': 45.0,
#  'count': 1,
#  'start': datetime.datetime(2018, 11, 1, 10, 57, 20)}
# {'amount': 6.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 10, 57, 23)}
# {'amount': 51.0,
#  'count': 4,
#  'start': datetime.datetime(2018, 11, 1, 10, 57, 25)}
# {'amount': 8.7, 'count': 4, 'start': datetime.datetime(2018, 11, 1, 10, 57, 31)}
# {'amount': 17.1,
#  'count': 1,
#  'start': datetime.datetime(2018, 11, 1, 10, 57, 32)}
# {'amount': 8.7, 'count': 2, 'start': datetime.datetime(2018, 11, 1, 10, 57, 38)}
# {'amount': 13.8,
#  'count': 4,
#  'start': datetime.datetime(2018, 11, 1, 10, 57, 53)}
# {'amount': 9.3, 'count': 6, 'start': datetime.datetime(2018, 11, 1, 10, 58, 1)}
# {'amount': 15.1, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 10, 58, 2)}
# {'amount': 18.9, 'count': 2, 'start': datetime.datetime(2018, 11, 1, 10, 58, 2)}
# {'amount': 21.9, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 10, 58, 5)}
# {'amount': 9.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 10, 58, 8)}
# {'amount': 8.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 10, 58, 17)}
# {'amount': 5.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 10, 58, 29)}
# {'amount': 21.3,
#  'count': 1,
#  'start': datetime.datetime(2018, 11, 1, 10, 58, 31)}
# {'amount': 4.8, 'count': 4, 'start': datetime.datetime(2018, 11, 1, 10, 58, 31)}
# {'amount': 10.3,
#  'count': 2,
#  'start': datetime.datetime(2018, 11, 1, 10, 58, 34)}
# {'amount': 12.8,
#  'count': 2,
#  'start': datetime.datetime(2018, 11, 1, 10, 58, 37)}
# {'amount': 11.8,
#  'count': 1,
#  'start': datetime.datetime(2018, 11, 1, 10, 58, 39)}
# {'amount': 11.3,
#  'count': 1,
#  'start': datetime.datetime(2018, 11, 1, 10, 58, 43)}
# {'amount': 23.7,
#  'count': 1,
#  'start': datetime.datetime(2018, 11, 1, 10, 58, 46)}
# {'amount': 49.2,
#  'count': 1,
#  'start': datetime.datetime(2018, 11, 1, 10, 58, 47)}
# {'amount': 9.3, 'count': 2, 'start': datetime.datetime(2018, 11, 1, 10, 58, 55)}
# {'amount': 26.8, 'count': 2, 'start': datetime.datetime(2018, 11, 1, 10, 59, 1)}
# {'amount': 13.5, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 10, 59, 3)}
# {'amount': 24.9, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 10, 59, 7)}
# {'amount': 15.3,
#  'count': 1,
#  'start': datetime.datetime(2018, 11, 1, 10, 59, 14)}
# {'amount': 11.7,
#  'count': 1,
#  'start': datetime.datetime(2018, 11, 1, 10, 59, 16)}
# {'amount': 6.9, 'count': 0, 'start': datetime.datetime(2018, 11, 1, 10, 59, 22)}
# {'amount': 15.0,
#  'count': 1,
#  'start': datetime.datetime(2018, 11, 1, 10, 59, 22)}
# {'amount': 11.1,
#  'count': 1,
#  'start': datetime.datetime(2018, 11, 1, 10, 59, 24)}
# {'amount': 10.8,
#  'count': 1,
#  'start': datetime.datetime(2018, 11, 1, 10, 59, 29)}
# {'amount': 6.9, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 10, 59, 33)}
# {'amount': 17.3,
#  'count': 2,
#  'start': datetime.datetime(2018, 11, 1, 10, 59, 33)}
# {'amount': 10.8,
#  'count': 1,
#  'start': datetime.datetime(2018, 11, 1, 10, 59, 36)}
# {'amount': 16.5,
#  'count': 1,
#  'start': datetime.datetime(2018, 11, 1, 10, 59, 37)}
# {'amount': 19.5,
#  'count': 4,
#  'start': datetime.datetime(2018, 11, 1, 10, 59, 41)}
# {'amount': 20.3,
#  'count': 1,
#  'start': datetime.datetime(2018, 11, 1, 10, 59, 41)}
# {'amount': 13.5,
#  'count': 2,
#  'start': datetime.datetime(2018, 11, 1, 10, 59, 50)}
# {'amount': 4.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 10, 59, 53)}
# {'amount': 11.3,
#  'count': 1,
#  'start': datetime.datetime(2018, 11, 1, 10, 59, 55)}
# {'amount': 16.2,
#  'count': 1,
#  'start': datetime.datetime(2018, 11, 1, 10, 59, 59)}
# {'amount': 11.0, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 11, 0, 3)}
# {'amount': 8.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 11, 0, 6)}
# {'amount': 10.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 11, 0, 7)}
# {'amount': 16.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 11, 0, 9)}
# {'amount': 13.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 11, 0, 9)}
# {'amount': 9.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 11, 0, 25)}
# {'amount': 16.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 11, 0, 32)}
# {'amount': 12.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 11, 0, 32)}
# {'amount': 20.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 11, 0, 40)}
# {'amount': 20.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 11, 0, 41)}
# {'amount': 11.2, 'count': 3, 'start': datetime.datetime(2018, 11, 1, 11, 0, 41)}
# {'amount': 3.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 11, 0, 42)}
# {'amount': 21.0, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 11, 0, 43)}
# {'amount': 18.8, 'count': 2, 'start': datetime.datetime(2018, 11, 1, 11, 0, 46)}
# {'amount': 12.8, 'count': 3, 'start': datetime.datetime(2018, 11, 1, 11, 0, 46)}
# {'amount': 7.5, 'count': 5, 'start': datetime.datetime(2018, 11, 1, 11, 0, 52)}
# {'amount': 38.0, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 11, 0, 53)}
# {'amount': 18.5, 'count': 5, 'start': datetime.datetime(2018, 11, 1, 11, 0, 56)}
# {'amount': 18.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 11, 0, 57)}
# {'amount': 17.1, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 11, 1, 3)}
# {'amount': 63.5, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 11, 1, 5)}
# {'amount': 23.5, 'count': 2, 'start': datetime.datetime(2018, 11, 1, 11, 1, 6)}
# {'amount': 6.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 11, 1, 6)}
# {'amount': 14.7, 'count': 0, 'start': datetime.datetime(2018, 11, 1, 11, 1, 16)}
# {'amount': 8.8, 'count': 3, 'start': datetime.datetime(2018, 11, 1, 11, 1, 19)}
# {'amount': 19.5, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 11, 1, 20)}
# {'amount': 6.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 11, 1, 26)}
# {'amount': 15.3, 'count': 3, 'start': datetime.datetime(2018, 11, 1, 11, 1, 29)}
# {'amount': 23.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 11, 1, 29)}
# {'amount': 19.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 11, 1, 32)}
# {'amount': 147.7,
#  'count': 1,
#  'start': datetime.datetime(2018, 11, 1, 11, 1, 32)}
# {'amount': 10.3, 'count': 4, 'start': datetime.datetime(2018, 11, 1, 11, 1, 39)}
# {'amount': 8.1, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 11, 1, 43)}
# {'amount': 14.1, 'count': 2, 'start': datetime.datetime(2018, 11, 1, 11, 1, 44)}
# {'amount': 26.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 11, 1, 46)}
# {'amount': 16.5, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 11, 2)}
# {'amount': 18.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 11, 2, 1)}
# {'amount': 21.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 11, 2, 5)}
# {'amount': 34.2, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 11, 2, 13)}
# {'amount': 29.7, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 11, 2, 15)}
# {'amount': 12.9, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 11, 2, 16)}
# {'amount': 5.7, 'count': 2, 'start': datetime.datetime(2018, 11, 1, 11, 2, 16)}
# {'amount': 5.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 11, 2, 19)}
# {'amount': 27.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 11, 2, 19)}
# {'amount': 4.7, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 11, 2, 22)}
# {'amount': 9.9, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 11, 2, 25)}
# {'amount': 8.8, 'count': 2, 'start': datetime.datetime(2018, 11, 1, 11, 2, 27)}
# {'amount': 12.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 11, 2, 30)}
# {'amount': 7.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 11, 2, 33)}
# {'amount': 11.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 11, 2, 35)}
# {'amount': 12.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 11, 2, 41)}
# {'amount': 6.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 11, 2, 43)}
# {'amount': 9.7, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 11, 2, 44)}
# {'amount': 14.3, 'count': 2, 'start': datetime.datetime(2018, 11, 1, 11, 2, 45)}
# {'amount': 6.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 11, 2, 46)}
# {'amount': 9.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 11, 2, 48)}
# {'amount': 8.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 11, 2, 56)}
# {'amount': 9.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 11, 2, 57)}
# {'amount': 18.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 11, 3, 2)}
# {'amount': 14.1, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 11, 3, 3)}
# {'amount': 58.8, 'count': 4, 'start': datetime.datetime(2018, 11, 1, 11, 3, 17)}
# {'amount': 106.0,
#  'count': 2,
#  'start': datetime.datetime(2018, 11, 1, 11, 3, 18)}
# {'amount': 13.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 11, 3, 19)}
# {'amount': 16.5, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 11, 3, 21)}
# {'amount': 12.9, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 11, 3, 23)}
# {'amount': 15.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 11, 3, 24)}
# {'amount': 28.9, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 11, 3, 26)}
# {'amount': 55.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 11, 3, 28)}
# {'amount': 8.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 11, 3, 31)}
# {'amount': 17.1, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 11, 3, 31)}
# {'amount': 21.1, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 11, 3, 38)}
# {'amount': 8.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 11, 3, 39)}
# {'amount': 24.9, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 11, 3, 41)}
# {'amount': 35.7, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 11, 3, 43)}
# {'amount': 21.6, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 11, 3, 47)}
# {'amount': 5.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 11, 3, 53)}
# {'amount': 16.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 11, 3, 54)}
# {'amount': 11.3, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 11, 3, 56)}
# {'amount': 17.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 11, 3, 56)}
# {'amount': 25.5, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 11, 4)}
# {'amount': 4.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 11, 4, 2)}
# {'amount': 6.8, 'count': 5, 'start': datetime.datetime(2018, 11, 1, 11, 4, 3)}
# {'amount': 13.0, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 11, 4, 5)}
# {'amount': 14.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 11, 4, 6)}
# {'amount': 13.5, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 11, 4, 8)}
# {'amount': 7.8, 'count': 1, 'start': datetime.datetime(2018, 11, 1, 11, 4, 8)}
